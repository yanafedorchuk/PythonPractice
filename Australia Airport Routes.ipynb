# %%
import numpy as np
import pandas as pd
from numpy import nan as NA

# %%
airport = pd.read_csv('airports.csv', names = ['Aiport', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 'Type', 'Source'])
airport
# Out:
#       Aiport                                         Name                City  \
# 0          1                               Goroka Airport              Goroka
# 1          2                               Madang Airport              Madang
# 2          3                 Mount Hagen Kagamuga Airport         Mount Hagen
# 3          4                               Nadzab Airport              Nadzab
# 4          5  Port Moresby Jacksons International Airport        Port Moresby
# 5          6                  Wewak International Airport               Wewak
# 6          7                           Narsarsuaq Airport        Narssarssuaq
# 7          8                      Godthaab / Nuuk Airport            Godthaab
# 8          9                        Kangerlussuaq Airport         Sondrestrom
# 9         10                               Thule Air Base               Thule
# 10        11                             Akureyri Airport            Akureyri
# 11        12                          Egilsstaðir Airport         Egilsstadir
# 12        13                         Hornafjörður Airport                Hofn
# 13        14                              Húsavík Airport             Husavik
# 14        15                           Ísafjörður Airport          Isafjordur
# 15        16               Keflavik International Airport            Keflavik
# 16        17                       Patreksfjörður Airport      Patreksfjordur
# 17        18                            Reykjavik Airport           Reykjavik
# 18        19                         Siglufjörður Airport        Siglufjordur
# 19        20                       Vestmannaeyjar Airport      Vestmannaeyjar
# 20        21                      Sault Ste Marie Airport  Sault Sainte Marie
# 21        22               Winnipeg / St. Andrews Airport            Winnipeg
# 22        23            Halifax / CFB Shearwater Heliport             Halifax
# 23        24                          St. Anthony Airport         St. Anthony
# 24        25                  Tofino / Long Beach Airport              Tofino
# 25        26                             Kugaaruk Airport           Pelly Bay
# 26        27                          Baie Comeau Airport         Baie Comeau
# 27        28                               CFB Bagotville          Bagotville
# 28        29                           Baker Lake Airport          Baker Lake
# 29        30                       Campbell River Airport      Campbell River
# ...      ...                                          ...                 ...
# 7154   12028                               Kerang Airport                 NaN
# 7155   12029                              Kempsey Airport                 NaN
# 7156   12030                             Kingaroy Airport                 NaN
# 7157   12031                       Latrobe Valley Airport             Morwell
# 7158   12032                              Mareeba Airport                 NaN
# 7159   12033                              Ngukurr Airport                 NaN
# 7160   12034                            Narromine Airport                 NaN
# 7161   12035                           Port Pirie Airport                 NaN
# 7162   12036                             Smithton Airport                 NaN
# 7163   12037                            Snake Bay Airport                 NaN
# 7164   12038                              Stawell Airport                 NaN
# 7165   12039                           Tibooburra Airport                 NaN
# 7166   12040                                Tumut Airport                 NaN
# 7167   12041                           Wangaratta Airport                 NaN
# 7168   12042                        Warracknabeal Airport                 NaN
# 7169   12043                               Warren Airport                 NaN
# 7170   12044                            West Sale Airport                Sale
# 7171   12045                         West Wyalong Airport        West Wyalong
# 7172   12046                                Young Airport                 NaN
# 7173   12047                        Guangzhou MR Air Base            Guanghua
# 7174   12048                    Shiyan Wudangshan Airport              Shiyan
# 7175   12049                             Sunchon Air Base             Sunchon
# 7176   12050                             Huatugou Airport             Mengnai
# 7177   12051                           Baruun Urt Airport                 NaN
# 7178   12052                               Bengbu Airport              Bengbu
# 7179   12053                               Rugao Air Base               Rugao
# 7180   12054                                Wuhu Air Base                Wuhu
# 7181   12055                             Shanshan Airport            Shanshan
# 7182   12056                        Yingkou Lanqi Airport             Yingkou
# 7183   12057                      Shenyang Dongta Airport            Shenyang
#
#                Country IATA  ICAO   Latitude   Longitude  Altitude Timezone  \
# 0     Papua New Guinea  GKA  AYGA  -6.081690  145.391998      5282       10
# 1     Papua New Guinea  MAG  AYMD  -5.207080  145.789001        20       10
# 2     Papua New Guinea  HGU  AYMH  -5.826790  144.296005      5388       10
# 3     Papua New Guinea  LAE  AYNZ  -6.569803  146.725977       239       10
# 4     Papua New Guinea  POM  AYPY  -9.443380  147.220001       146       10
# 5     Papua New Guinea  WWK  AYWK  -3.583830  143.669006        19       10
# 6            Greenland  UAK  BGBW  61.160500  -45.425999       112       -3
# 7            Greenland  GOH  BGGH  64.190903  -51.678101       283       -3
# 8            Greenland  SFJ  BGSF  67.012222  -50.711603       165       -3
# 9            Greenland  THU  BGTL  76.531197  -68.703201       251       -4
# 10             Iceland  AEY  BIAR  65.660004  -18.072701         6        0
# 11             Iceland  EGS  BIEG  65.283302  -14.401400        76        0
# 12             Iceland  HFN  BIHN  64.295601  -15.227200        24        0
# 13             Iceland  HZK  BIHU  65.952301  -17.426001        48        0
# 14             Iceland  IFJ  BIIS  66.058098  -23.135300         8        0
# 15             Iceland  KEF  BIKF  63.985001  -22.605600       171        0
# 16             Iceland  PFJ  BIPA  65.555801  -23.965000        11        0
# 17             Iceland  RKV  BIRK  64.129997  -21.940599        48        0
# 18             Iceland  SIJ  BISI  66.133301  -18.916700        10        0
# 19             Iceland  VEY  BIVM  63.424301  -20.278900       326        0
# 20              Canada  YAM  CYAM  46.485001  -84.509399       630       -5
# 21              Canada  YAV  CYAV  50.056400  -97.032501       760       -6
# 22              Canada  YAW  CYAW  44.639702  -63.499401       144       -4
# 23              Canada  YAY  CYAY  51.391899  -56.083099       108     -3.5
# 24              Canada  YAZ  CYAZ  49.079833 -125.775583        80       -8
# 25              Canada  YBB  CYBB  68.534401  -89.808098        56       -7
# 26              Canada  YBC  CYBC  49.132500  -68.204399        71       -5
# 27              Canada  YBG  CYBG  48.330601  -70.996399       522       -5
# 28              Canada  YBK  CYBK  64.298897  -96.077797        59       -6
# 29              Canada  YBL  CYBL  49.950802 -125.271004       346       -8
# ...                ...  ...   ...        ...         ...       ...      ...
# 7154         Australia  KRA  YKER -35.751400  143.938995       254       \N
# 7155         Australia  KPS  YKMP -31.074400  152.770004        54       \N
# 7156         Australia  KGY  YKRY -26.580799  151.841003      1492       \N
# 7157         Australia  TGN  YLTV -38.207199  146.470001       180       \N
# 7158         Australia  MRG  YMBA -17.069201  145.419006      1560       \N
# 7159         Australia  RPM  YNGU -14.722800  134.746994        45       \N
# 7160         Australia  QRM  YNRM -32.214699  148.225006       782       \N
# 7161         Australia  PPI  YPIR -33.238899  137.994995        40       \N
# 7162         Australia  SIO  YSMI -40.834999  145.084000        31       \N
# 7163         Australia  SNB  YSNB -11.422800  130.654007       173       \N
# 7164         Australia  SWC  YSWL -37.071701  142.740997       807       \N
# 7165         Australia  TYB  YTIB -29.451099  142.057999       584       \N
# 7166         Australia  TUM  YTMU -35.262798  148.240997       878       \N
# 7167         Australia  WGT  YWGT -36.415798  146.307007       504       \N
# 7168         Australia  WKB  YWKB -36.321098  142.419006       397       \N
# 7169         Australia  QRR  YWRN -31.733299  147.802994       669       \N
# 7170         Australia  SXE  YWSL -38.090827  146.965335        72       \N
# 7171         Australia  WWY  YWWL -33.937199  147.190994       859       \N
# 7172         Australia  NGA  YYNG -34.255600  148.248001      1267       \N
# 7173             China  LHK  ZHGH  32.389400  111.695000         0       \N
# 7174             China  WDS  ZHSY  32.591667  110.907778         0       \N
# 7175       North Korea   \N  ZKSC  39.415699  125.894997       141       \N
# 7176             China  HTT  ZLHX  38.201984   90.841495      2945       \N
# 7177          Mongolia  UUN  ZMBU  46.660301  113.285004      3205       \N
# 7178             China  BFU  ZSBB  32.847733  117.320244       100       \N
# 7179             China  RUG  ZSRG  32.257885  120.501656         0       \N
# 7180             China  WHU  ZSWU  31.390600  118.408997         0       \N
# 7181             China  SXJ  ZWSS  42.911701   90.247498         0       \N
# 7182             China  YKH  ZYYK  40.542524  122.358600         0       \N
# 7183             China   \N  ZYYY  41.784401  123.496002         0       \N
#
#      DST Tz database time zone     Type       Source
# 0      U  Pacific/Port_Moresby  airport  OurAirports
# 1      U  Pacific/Port_Moresby  airport  OurAirports
# 2      U  Pacific/Port_Moresby  airport  OurAirports
# 3      U  Pacific/Port_Moresby  airport  OurAirports
# 4      U  Pacific/Port_Moresby  airport  OurAirports
# 5      U  Pacific/Port_Moresby  airport  OurAirports
# 6      E       America/Godthab  airport  OurAirports
# 7      E       America/Godthab  airport  OurAirports
# 8      E       America/Godthab  airport  OurAirports
# 9      E         America/Thule  airport  OurAirports
# 10     N    Atlantic/Reykjavik  airport  OurAirports
# 11     N    Atlantic/Reykjavik  airport  OurAirports
# 12     N    Atlantic/Reykjavik  airport  OurAirports
# 13     N    Atlantic/Reykjavik  airport  OurAirports
# 14     N    Atlantic/Reykjavik  airport  OurAirports
# 15     N    Atlantic/Reykjavik  airport  OurAirports
# 16     N    Atlantic/Reykjavik  airport  OurAirports
# 17     N    Atlantic/Reykjavik  airport  OurAirports
# 18     N    Atlantic/Reykjavik  airport  OurAirports
# 19     N    Atlantic/Reykjavik  airport  OurAirports
# 20     A       America/Toronto  airport  OurAirports
# 21     A      America/Winnipeg  airport  OurAirports
# 22     A       America/Halifax  airport  OurAirports
# 23     A      America/St_Johns  airport  OurAirports
# 24     A     America/Vancouver  airport  OurAirports
# 25     A      America/Edmonton  airport  OurAirports
# 26     A       America/Toronto  airport  OurAirports
# 27     A       America/Toronto  airport  OurAirports
# 28     A      America/Winnipeg  airport  OurAirports
# 29     A     America/Vancouver  airport  OurAirports
# ...   ..                   ...      ...          ...
# 7154  \N                    \N  airport  OurAirports
# 7155  \N                    \N  airport  OurAirports
# 7156  \N                    \N  airport  OurAirports
# 7157  \N                    \N  airport  OurAirports
# 7158  \N                    \N  airport  OurAirports
# 7159  \N                    \N  airport  OurAirports
# 7160  \N                    \N  airport  OurAirports
# 7161  \N                    \N  airport  OurAirports
# 7162  \N                    \N  airport  OurAirports
# 7163  \N                    \N  airport  OurAirports
# 7164  \N                    \N  airport  OurAirports
# 7165  \N                    \N  airport  OurAirports
# 7166  \N                    \N  airport  OurAirports
# 7167  \N                    \N  airport  OurAirports
# 7168  \N                    \N  airport  OurAirports
# 7169  \N                    \N  airport  OurAirports
# 7170  \N                    \N  airport  OurAirports
# 7171  \N                    \N  airport  OurAirports
# 7172  \N                    \N  airport  OurAirports
# 7173  \N                    \N  airport  OurAirports
# 7174  \N                    \N  airport  OurAirports
# 7175  \N                    \N  airport  OurAirports
# 7176  \N                    \N  airport  OurAirports
# 7177  \N                    \N  airport  OurAirports
# 7178  \N                    \N  airport  OurAirports
# 7179  \N                    \N  airport  OurAirports
# 7180  \N                    \N  airport  OurAirports
# 7181  \N                    \N  airport  OurAirports
# 7182  \N                    \N  airport  OurAirports
# 7183  \N                    \N  airport  OurAirports
#
# [7184 rows x 14 columns]

# %%
AUS=['Australia']

# %%
new=airport[airport['Country'].isin(AUS)]
new
# Out:
#       Aiport                                 Name           City    Country  \
# 3113    3317         Brisbane Archerfield Airport       Brisbane  Australia
# 3114    3318           Northern Peninsula Airport       Amberley  Australia
# 3115    3319                Alice Springs Airport  Alice Springs  Australia
# 3116    3320       Brisbane International Airport       Brisbane  Australia
# 3117    3321                   Gold Coast Airport    Coolangatta  Australia
# 3118    3322         Cairns International Airport         Cairns  Australia
# 3119    3323                  Charleville Airport   Charlieville  Australia
# 3120    3324                    Mount Isa Airport      Mount Isa  Australia
# 3121    3325               Sunshine Coast Airport   Maroochydore  Australia
# 3122    3326                       Mackay Airport         Mackay  Australia
# 3123    3328  Proserpine Whitsunday Coast Airport    Prosserpine  Australia
# 3124    3329                  Rockhampton Airport    Rockhampton  Australia
# 3125    3330                   Townsville Airport     Townsville  Australia
# 3126    3331                        Weipa Airport          Weipa  Australia
# 3127    3332                       Avalon Airport         Avalon  Australia
# 3128    3333                       Albury Airport         Albury  Australia
# 3129    3334           Melbourne Essendon Airport      Melbourne  Australia
# 3130    3335                  RAAF Base East Sale      East Sale  Australia
# 3131    3336         Hobart International Airport         Hobart  Australia
# 3132    3337                   Launceston Airport     Launceston  Australia
# 3133    3338          Melbourne Moorabbin Airport      Melbourne  Australia
# 3134    3339      Melbourne International Airport      Melbourne  Australia
# 3135    3340       RAAF Williams, Point Cook Base     Point Cook  Australia
# 3136    3341       Adelaide International Airport       Adelaide  Australia
# 3137    3343                  RAAF Base Edinburgh      Edinburgh  Australia
# 3138    3344               Perth Jandakot Airport          Perth  Australia
# 3139    3345                     Karratha Airport       Karratha  Australia
# 3140    3346           Kalgoorlie Boulder Airport     Kalgoorlie  Australia
# 3141    3347                    Kununurra Airport      Kununurra  Australia
# 3142    3348                    Learmonth Airport      Learmonth  Australia
# ...      ...                                  ...            ...        ...
# 7143   12017                       Corowa Airport            NaN  Australia
# 7144   12018                     Corryong Airport            NaN  Australia
# 7145   12019                  Cootamundra Airport            NaN  Australia
# 7146   12020                  Dirranbandi Airport            NaN  Australia
# 7147   12021                   Deniliquin Airport     Deniliquin  Australia
# 7148   12022                       Dysart Airport            NaN  Australia
# 7149   12023                       Echuca Airport            NaN  Australia
# 7150   12024                       Forbes Airport         Forbes  Australia
# 7151   12025                     Gunnedah Airport            NaN  Australia
# 7152   12026                          Hay Airport            NaN  Australia
# 7153   12027                     Hopetoun Airport            NaN  Australia
# 7154   12028                       Kerang Airport            NaN  Australia
# 7155   12029                      Kempsey Airport            NaN  Australia
# 7156   12030                     Kingaroy Airport            NaN  Australia
# 7157   12031               Latrobe Valley Airport        Morwell  Australia
# 7158   12032                      Mareeba Airport            NaN  Australia
# 7159   12033                      Ngukurr Airport            NaN  Australia
# 7160   12034                    Narromine Airport            NaN  Australia
# 7161   12035                   Port Pirie Airport            NaN  Australia
# 7162   12036                     Smithton Airport            NaN  Australia
# 7163   12037                    Snake Bay Airport            NaN  Australia
# 7164   12038                      Stawell Airport            NaN  Australia
# 7165   12039                   Tibooburra Airport            NaN  Australia
# 7166   12040                        Tumut Airport            NaN  Australia
# 7167   12041                   Wangaratta Airport            NaN  Australia
# 7168   12042                Warracknabeal Airport            NaN  Australia
# 7169   12043                       Warren Airport            NaN  Australia
# 7170   12044                    West Sale Airport           Sale  Australia
# 7171   12045                 West Wyalong Airport   West Wyalong  Australia
# 7172   12046                        Young Airport            NaN  Australia
#
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone DST  \
# 3113   \N  YBAF -27.570299  153.007996        63       10   O
# 3114  ABM  YBAM -10.950800  142.459000        34       10   O
# 3115  ASP  YBAS -23.806700  133.901993      1789      9.5   N
# 3116  BNE  YBBN -27.384199  153.117004        13       10   N
# 3117  OOL  YBCG -28.164400  153.505005        21       10   N
# 3118  CNS  YBCS -16.885799  145.755005        10       10   N
# 3119  CTL  YBCV -26.413300  146.261993      1003       10   O
# 3120  ISA  YBMA -20.663900  139.488998      1121       10   O
# 3121  MCY  YBMC -26.603300  153.091003        15       10   O
# 3122  MKY  YBMK -21.171700  149.179993        19       10   O
# 3123  PPP  YBPN -20.495001  148.552002        82       10   O
# 3124  ROK  YBRK -23.381901  150.475006        34       10   O
# 3125  TSV  YBTL -19.252501  146.764999        18       10   N
# 3126  WEI  YBWP -12.678600  141.925003        63       10   O
# 3127  AVV  YMAV -38.039398  144.468994        35       10   O
# 3128  ABX  YMAY -36.067799  146.957993       539       10   O
# 3129  MEB  YMEN -37.728100  144.901993       282       10   O
# 3130   \N  YMES -38.098900  147.149002        23       10   O
# 3131  HBA  YMHB -42.836102  147.509995        13       10   O
# 3132  LST  YMLT -41.545300  147.214005       562       10   O
# 3133  MBW  YMMB -37.975800  145.102005        50       10   O
# 3134  MEL  YMML -37.673302  144.843002       434       10   O
# 3135   \N  YMPC -37.932201  144.753006        14       10   O
# 3136  ADL  YPAD -34.945000  138.531006        20      9.5   O
# 3137   \N  YPED -34.702499  138.621002        67      9.5   O
# 3138  JAD  YPJT -32.097500  115.880997        99        8   O
# 3139  KTA  YPKA -20.712200  116.773003        29        8   O
# 3140  KGI  YPKG -30.789400  121.461998      1203        8   O
# 3141  KNX  YPKU -15.778100  128.707993       145        8   O
# 3142  LEA  YPLM -22.235600  114.088997        19        8   O
# ...   ...   ...        ...         ...       ...      ...  ..
# 7143  CWW  YCOR -35.994701  146.356995       469       \N  \N
# 7144  CYG  YCRG -36.182800  147.888000       963       \N  \N
# 7145  CMD  YCTM -34.623901  148.028000      1110       \N  \N
# 7146  DRN  YDBI -28.591700  148.216995       567       \N  \N
# 7147  DNQ  YDLQ -35.559399  144.945999       316       \N  \N
# 7148  DYA  YDYS -22.622200  148.363998       670       \N  \N
# 7149  ECH  YECH -36.157200  144.761993       323       \N  \N
# 7150  FRB  YFBS -33.363602  147.934998       760       \N  \N
# 7151  GUH  YGDH -30.961100  150.251007       863       \N  \N
# 7152  HXX  YHAY -34.531399  144.830002       305       \N  \N
# 7153  HTU  YHPN -35.715302  142.360001       256       \N  \N
# 7154  KRA  YKER -35.751400  143.938995       254       \N  \N
# 7155  KPS  YKMP -31.074400  152.770004        54       \N  \N
# 7156  KGY  YKRY -26.580799  151.841003      1492       \N  \N
# 7157  TGN  YLTV -38.207199  146.470001       180       \N  \N
# 7158  MRG  YMBA -17.069201  145.419006      1560       \N  \N
# 7159  RPM  YNGU -14.722800  134.746994        45       \N  \N
# 7160  QRM  YNRM -32.214699  148.225006       782       \N  \N
# 7161  PPI  YPIR -33.238899  137.994995        40       \N  \N
# 7162  SIO  YSMI -40.834999  145.084000        31       \N  \N
# 7163  SNB  YSNB -11.422800  130.654007       173       \N  \N
# 7164  SWC  YSWL -37.071701  142.740997       807       \N  \N
# 7165  TYB  YTIB -29.451099  142.057999       584       \N  \N
# 7166  TUM  YTMU -35.262798  148.240997       878       \N  \N
# 7167  WGT  YWGT -36.415798  146.307007       504       \N  \N
# 7168  WKB  YWKB -36.321098  142.419006       397       \N  \N
# 7169  QRR  YWRN -31.733299  147.802994       669       \N  \N
# 7170  SXE  YWSL -38.090827  146.965335        72       \N  \N
# 7171  WWY  YWWL -33.937199  147.190994       859       \N  \N
# 7172  NGA  YYNG -34.255600  148.248001      1267       \N  \N
#
#      Tz database time zone     Type       Source
# 3113    Australia/Brisbane  airport  OurAirports
# 3114    Australia/Brisbane  airport  OurAirports
# 3115      Australia/Darwin  airport  OurAirports
# 3116    Australia/Brisbane  airport  OurAirports
# 3117    Australia/Brisbane  airport  OurAirports
# 3118    Australia/Brisbane  airport  OurAirports
# 3119    Australia/Brisbane  airport  OurAirports
# 3120    Australia/Brisbane  airport  OurAirports
# 3121    Australia/Brisbane  airport  OurAirports
# 3122    Australia/Brisbane  airport  OurAirports
# 3123    Australia/Brisbane  airport  OurAirports
# 3124    Australia/Brisbane  airport  OurAirports
# 3125    Australia/Brisbane  airport  OurAirports
# 3126    Australia/Brisbane  airport  OurAirports
# 3127      Australia/Hobart  airport  OurAirports
# 3128      Australia/Sydney  airport  OurAirports
# 3129      Australia/Hobart  airport  OurAirports
# 3130      Australia/Hobart  airport  OurAirports
# 3131   Australia/Melbourne  airport  OurAirports
# 3132   Australia/Melbourne  airport  OurAirports
# 3133      Australia/Hobart  airport  OurAirports
# 3134      Australia/Hobart  airport  OurAirports
# 3135      Australia/Hobart  airport  OurAirports
# 3136    Australia/Adelaide  airport  OurAirports
# 3137    Australia/Adelaide  airport  OurAirports
# 3138       Australia/Perth  airport  OurAirports
# 3139       Australia/Perth  airport  OurAirports
# 3140       Australia/Perth  airport  OurAirports
# 3141       Australia/Perth  airport  OurAirports
# 3142       Australia/Perth  airport  OurAirports
# ...                    ...      ...          ...
# 7143                    \N  airport  OurAirports
# 7144                    \N  airport  OurAirports
# 7145                    \N  airport  OurAirports
# 7146                    \N  airport  OurAirports
# 7147                    \N  airport  OurAirports
# 7148                    \N  airport  OurAirports
# 7149                    \N  airport  OurAirports
# 7150                    \N  airport  OurAirports
# 7151                    \N  airport  OurAirports
# 7152                    \N  airport  OurAirports
# 7153                    \N  airport  OurAirports
# 7154                    \N  airport  OurAirports
# 7155                    \N  airport  OurAirports
# 7156                    \N  airport  OurAirports
# 7157                    \N  airport  OurAirports
# 7158                    \N  airport  OurAirports
# 7159                    \N  airport  OurAirports
# 7160                    \N  airport  OurAirports
# 7161                    \N  airport  OurAirports
# 7162                    \N  airport  OurAirports
# 7163                    \N  airport  OurAirports
# 7164                    \N  airport  OurAirports
# 7165                    \N  airport  OurAirports
# 7166                    \N  airport  OurAirports
# 7167                    \N  airport  OurAirports
# 7168                    \N  airport  OurAirports
# 7169                    \N  airport  OurAirports
# 7170                    \N  airport  OurAirports
# 7171                    \N  airport  OurAirports
# 7172                    \N  airport  OurAirports
#
# [296 rows x 14 columns]

# %%
new=new.replace('\\N',NA)
new
# Out:
#       Aiport                                 Name           City    Country  \
# 3113    3317         Brisbane Archerfield Airport       Brisbane  Australia
# 3114    3318           Northern Peninsula Airport       Amberley  Australia
# 3115    3319                Alice Springs Airport  Alice Springs  Australia
# 3116    3320       Brisbane International Airport       Brisbane  Australia
# 3117    3321                   Gold Coast Airport    Coolangatta  Australia
# 3118    3322         Cairns International Airport         Cairns  Australia
# 3119    3323                  Charleville Airport   Charlieville  Australia
# 3120    3324                    Mount Isa Airport      Mount Isa  Australia
# 3121    3325               Sunshine Coast Airport   Maroochydore  Australia
# 3122    3326                       Mackay Airport         Mackay  Australia
# 3123    3328  Proserpine Whitsunday Coast Airport    Prosserpine  Australia
# 3124    3329                  Rockhampton Airport    Rockhampton  Australia
# 3125    3330                   Townsville Airport     Townsville  Australia
# 3126    3331                        Weipa Airport          Weipa  Australia
# 3127    3332                       Avalon Airport         Avalon  Australia
# 3128    3333                       Albury Airport         Albury  Australia
# 3129    3334           Melbourne Essendon Airport      Melbourne  Australia
# 3130    3335                  RAAF Base East Sale      East Sale  Australia
# 3131    3336         Hobart International Airport         Hobart  Australia
# 3132    3337                   Launceston Airport     Launceston  Australia
# 3133    3338          Melbourne Moorabbin Airport      Melbourne  Australia
# 3134    3339      Melbourne International Airport      Melbourne  Australia
# 3135    3340       RAAF Williams, Point Cook Base     Point Cook  Australia
# 3136    3341       Adelaide International Airport       Adelaide  Australia
# 3137    3343                  RAAF Base Edinburgh      Edinburgh  Australia
# 3138    3344               Perth Jandakot Airport          Perth  Australia
# 3139    3345                     Karratha Airport       Karratha  Australia
# 3140    3346           Kalgoorlie Boulder Airport     Kalgoorlie  Australia
# 3141    3347                    Kununurra Airport      Kununurra  Australia
# 3142    3348                    Learmonth Airport      Learmonth  Australia
# ...      ...                                  ...            ...        ...
# 7143   12017                       Corowa Airport            NaN  Australia
# 7144   12018                     Corryong Airport            NaN  Australia
# 7145   12019                  Cootamundra Airport            NaN  Australia
# 7146   12020                  Dirranbandi Airport            NaN  Australia
# 7147   12021                   Deniliquin Airport     Deniliquin  Australia
# 7148   12022                       Dysart Airport            NaN  Australia
# 7149   12023                       Echuca Airport            NaN  Australia
# 7150   12024                       Forbes Airport         Forbes  Australia
# 7151   12025                     Gunnedah Airport            NaN  Australia
# 7152   12026                          Hay Airport            NaN  Australia
# 7153   12027                     Hopetoun Airport            NaN  Australia
# 7154   12028                       Kerang Airport            NaN  Australia
# 7155   12029                      Kempsey Airport            NaN  Australia
# 7156   12030                     Kingaroy Airport            NaN  Australia
# 7157   12031               Latrobe Valley Airport        Morwell  Australia
# 7158   12032                      Mareeba Airport            NaN  Australia
# 7159   12033                      Ngukurr Airport            NaN  Australia
# 7160   12034                    Narromine Airport            NaN  Australia
# 7161   12035                   Port Pirie Airport            NaN  Australia
# 7162   12036                     Smithton Airport            NaN  Australia
# 7163   12037                    Snake Bay Airport            NaN  Australia
# 7164   12038                      Stawell Airport            NaN  Australia
# 7165   12039                   Tibooburra Airport            NaN  Australia
# 7166   12040                        Tumut Airport            NaN  Australia
# 7167   12041                   Wangaratta Airport            NaN  Australia
# 7168   12042                Warracknabeal Airport            NaN  Australia
# 7169   12043                       Warren Airport            NaN  Australia
# 7170   12044                    West Sale Airport           Sale  Australia
# 7171   12045                 West Wyalong Airport   West Wyalong  Australia
# 7172   12046                        Young Airport            NaN  Australia
#
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone  DST  \
# 3113  NaN  YBAF -27.570299  153.007996        63       10    O
# 3114  ABM  YBAM -10.950800  142.459000        34       10    O
# 3115  ASP  YBAS -23.806700  133.901993      1789      9.5    N
# 3116  BNE  YBBN -27.384199  153.117004        13       10    N
# 3117  OOL  YBCG -28.164400  153.505005        21       10    N
# 3118  CNS  YBCS -16.885799  145.755005        10       10    N
# 3119  CTL  YBCV -26.413300  146.261993      1003       10    O
# 3120  ISA  YBMA -20.663900  139.488998      1121       10    O
# 3121  MCY  YBMC -26.603300  153.091003        15       10    O
# 3122  MKY  YBMK -21.171700  149.179993        19       10    O
# 3123  PPP  YBPN -20.495001  148.552002        82       10    O
# 3124  ROK  YBRK -23.381901  150.475006        34       10    O
# 3125  TSV  YBTL -19.252501  146.764999        18       10    N
# 3126  WEI  YBWP -12.678600  141.925003        63       10    O
# 3127  AVV  YMAV -38.039398  144.468994        35       10    O
# 3128  ABX  YMAY -36.067799  146.957993       539       10    O
# 3129  MEB  YMEN -37.728100  144.901993       282       10    O
# 3130  NaN  YMES -38.098900  147.149002        23       10    O
# 3131  HBA  YMHB -42.836102  147.509995        13       10    O
# 3132  LST  YMLT -41.545300  147.214005       562       10    O
# 3133  MBW  YMMB -37.975800  145.102005        50       10    O
# 3134  MEL  YMML -37.673302  144.843002       434       10    O
# 3135  NaN  YMPC -37.932201  144.753006        14       10    O
# 3136  ADL  YPAD -34.945000  138.531006        20      9.5    O
# 3137  NaN  YPED -34.702499  138.621002        67      9.5    O
# 3138  JAD  YPJT -32.097500  115.880997        99        8    O
# 3139  KTA  YPKA -20.712200  116.773003        29        8    O
# 3140  KGI  YPKG -30.789400  121.461998      1203        8    O
# 3141  KNX  YPKU -15.778100  128.707993       145        8    O
# 3142  LEA  YPLM -22.235600  114.088997        19        8    O
# ...   ...   ...        ...         ...       ...      ...  ...
# 7143  CWW  YCOR -35.994701  146.356995       469      NaN  NaN
# 7144  CYG  YCRG -36.182800  147.888000       963      NaN  NaN
# 7145  CMD  YCTM -34.623901  148.028000      1110      NaN  NaN
# 7146  DRN  YDBI -28.591700  148.216995       567      NaN  NaN
# 7147  DNQ  YDLQ -35.559399  144.945999       316      NaN  NaN
# 7148  DYA  YDYS -22.622200  148.363998       670      NaN  NaN
# 7149  ECH  YECH -36.157200  144.761993       323      NaN  NaN
# 7150  FRB  YFBS -33.363602  147.934998       760      NaN  NaN
# 7151  GUH  YGDH -30.961100  150.251007       863      NaN  NaN
# 7152  HXX  YHAY -34.531399  144.830002       305      NaN  NaN
# 7153  HTU  YHPN -35.715302  142.360001       256      NaN  NaN
# 7154  KRA  YKER -35.751400  143.938995       254      NaN  NaN
# 7155  KPS  YKMP -31.074400  152.770004        54      NaN  NaN
# 7156  KGY  YKRY -26.580799  151.841003      1492      NaN  NaN
# 7157  TGN  YLTV -38.207199  146.470001       180      NaN  NaN
# 7158  MRG  YMBA -17.069201  145.419006      1560      NaN  NaN
# 7159  RPM  YNGU -14.722800  134.746994        45      NaN  NaN
# 7160  QRM  YNRM -32.214699  148.225006       782      NaN  NaN
# 7161  PPI  YPIR -33.238899  137.994995        40      NaN  NaN
# 7162  SIO  YSMI -40.834999  145.084000        31      NaN  NaN
# 7163  SNB  YSNB -11.422800  130.654007       173      NaN  NaN
# 7164  SWC  YSWL -37.071701  142.740997       807      NaN  NaN
# 7165  TYB  YTIB -29.451099  142.057999       584      NaN  NaN
# 7166  TUM  YTMU -35.262798  148.240997       878      NaN  NaN
# 7167  WGT  YWGT -36.415798  146.307007       504      NaN  NaN
# 7168  WKB  YWKB -36.321098  142.419006       397      NaN  NaN
# 7169  QRR  YWRN -31.733299  147.802994       669      NaN  NaN
# 7170  SXE  YWSL -38.090827  146.965335        72      NaN  NaN
# 7171  WWY  YWWL -33.937199  147.190994       859      NaN  NaN
# 7172  NGA  YYNG -34.255600  148.248001      1267      NaN  NaN
#
#      Tz database time zone     Type       Source
# 3113    Australia/Brisbane  airport  OurAirports
# 3114    Australia/Brisbane  airport  OurAirports
# 3115      Australia/Darwin  airport  OurAirports
# 3116    Australia/Brisbane  airport  OurAirports
# 3117    Australia/Brisbane  airport  OurAirports
# 3118    Australia/Brisbane  airport  OurAirports
# 3119    Australia/Brisbane  airport  OurAirports
# 3120    Australia/Brisbane  airport  OurAirports
# 3121    Australia/Brisbane  airport  OurAirports
# 3122    Australia/Brisbane  airport  OurAirports
# 3123    Australia/Brisbane  airport  OurAirports
# 3124    Australia/Brisbane  airport  OurAirports
# 3125    Australia/Brisbane  airport  OurAirports
# 3126    Australia/Brisbane  airport  OurAirports
# 3127      Australia/Hobart  airport  OurAirports
# 3128      Australia/Sydney  airport  OurAirports
# 3129      Australia/Hobart  airport  OurAirports
# 3130      Australia/Hobart  airport  OurAirports
# 3131   Australia/Melbourne  airport  OurAirports
# 3132   Australia/Melbourne  airport  OurAirports
# 3133      Australia/Hobart  airport  OurAirports
# 3134      Australia/Hobart  airport  OurAirports
# 3135      Australia/Hobart  airport  OurAirports
# 3136    Australia/Adelaide  airport  OurAirports
# 3137    Australia/Adelaide  airport  OurAirports
# 3138       Australia/Perth  airport  OurAirports
# 3139       Australia/Perth  airport  OurAirports
# 3140       Australia/Perth  airport  OurAirports
# 3141       Australia/Perth  airport  OurAirports
# 3142       Australia/Perth  airport  OurAirports
# ...                    ...      ...          ...
# 7143                   NaN  airport  OurAirports
# 7144                   NaN  airport  OurAirports
# 7145                   NaN  airport  OurAirports
# 7146                   NaN  airport  OurAirports
# 7147                   NaN  airport  OurAirports
# 7148                   NaN  airport  OurAirports
# 7149                   NaN  airport  OurAirports
# 7150                   NaN  airport  OurAirports
# 7151                   NaN  airport  OurAirports
# 7152                   NaN  airport  OurAirports
# 7153                   NaN  airport  OurAirports
# 7154                   NaN  airport  OurAirports
# 7155                   NaN  airport  OurAirports
# 7156                   NaN  airport  OurAirports
# 7157                   NaN  airport  OurAirports
# 7158                   NaN  airport  OurAirports
# 7159                   NaN  airport  OurAirports
# 7160                   NaN  airport  OurAirports
# 7161                   NaN  airport  OurAirports
# 7162                   NaN  airport  OurAirports
# 7163                   NaN  airport  OurAirports
# 7164                   NaN  airport  OurAirports
# 7165                   NaN  airport  OurAirports
# 7166                   NaN  airport  OurAirports
# 7167                   NaN  airport  OurAirports
# 7168                   NaN  airport  OurAirports
# 7169                   NaN  airport  OurAirports
# 7170                   NaN  airport  OurAirports
# 7171                   NaN  airport  OurAirports
# 7172                   NaN  airport  OurAirports
#
# [296 rows x 14 columns]

# %%
air_aus = new[new['IATA'].str.len()==3]
air_aus
# Out:
#       Aiport                                 Name           City    Country  \
# 3114    3318           Northern Peninsula Airport       Amberley  Australia
# 3115    3319                Alice Springs Airport  Alice Springs  Australia
# 3116    3320       Brisbane International Airport       Brisbane  Australia
# 3117    3321                   Gold Coast Airport    Coolangatta  Australia
# 3118    3322         Cairns International Airport         Cairns  Australia
# 3119    3323                  Charleville Airport   Charlieville  Australia
# 3120    3324                    Mount Isa Airport      Mount Isa  Australia
# 3121    3325               Sunshine Coast Airport   Maroochydore  Australia
# 3122    3326                       Mackay Airport         Mackay  Australia
# 3123    3328  Proserpine Whitsunday Coast Airport    Prosserpine  Australia
# 3124    3329                  Rockhampton Airport    Rockhampton  Australia
# 3125    3330                   Townsville Airport     Townsville  Australia
# 3126    3331                        Weipa Airport          Weipa  Australia
# 3127    3332                       Avalon Airport         Avalon  Australia
# 3128    3333                       Albury Airport         Albury  Australia
# 3129    3334           Melbourne Essendon Airport      Melbourne  Australia
# 3131    3336         Hobart International Airport         Hobart  Australia
# 3132    3337                   Launceston Airport     Launceston  Australia
# 3133    3338          Melbourne Moorabbin Airport      Melbourne  Australia
# 3134    3339      Melbourne International Airport      Melbourne  Australia
# 3136    3341       Adelaide International Airport       Adelaide  Australia
# 3138    3344               Perth Jandakot Airport          Perth  Australia
# 3139    3345                     Karratha Airport       Karratha  Australia
# 3140    3346           Kalgoorlie Boulder Airport     Kalgoorlie  Australia
# 3141    3347                    Kununurra Airport      Kununurra  Australia
# 3142    3348                    Learmonth Airport      Learmonth  Australia
# 3143    3349   Port Hedland International Airport   Port Hedland  Australia
# 3145    3351          Perth International Airport          Perth  Australia
# 3146    3352                     Woomera Airfield        Woomera  Australia
# 3148    3354             Sydney Bankstown Airport         Sydney  Australia
# ...      ...                                  ...            ...        ...
# 7143   12017                       Corowa Airport            NaN  Australia
# 7144   12018                     Corryong Airport            NaN  Australia
# 7145   12019                  Cootamundra Airport            NaN  Australia
# 7146   12020                  Dirranbandi Airport            NaN  Australia
# 7147   12021                   Deniliquin Airport     Deniliquin  Australia
# 7148   12022                       Dysart Airport            NaN  Australia
# 7149   12023                       Echuca Airport            NaN  Australia
# 7150   12024                       Forbes Airport         Forbes  Australia
# 7151   12025                     Gunnedah Airport            NaN  Australia
# 7152   12026                          Hay Airport            NaN  Australia
# 7153   12027                     Hopetoun Airport            NaN  Australia
# 7154   12028                       Kerang Airport            NaN  Australia
# 7155   12029                      Kempsey Airport            NaN  Australia
# 7156   12030                     Kingaroy Airport            NaN  Australia
# 7157   12031               Latrobe Valley Airport        Morwell  Australia
# 7158   12032                      Mareeba Airport            NaN  Australia
# 7159   12033                      Ngukurr Airport            NaN  Australia
# 7160   12034                    Narromine Airport            NaN  Australia
# 7161   12035                   Port Pirie Airport            NaN  Australia
# 7162   12036                     Smithton Airport            NaN  Australia
# 7163   12037                    Snake Bay Airport            NaN  Australia
# 7164   12038                      Stawell Airport            NaN  Australia
# 7165   12039                   Tibooburra Airport            NaN  Australia
# 7166   12040                        Tumut Airport            NaN  Australia
# 7167   12041                   Wangaratta Airport            NaN  Australia
# 7168   12042                Warracknabeal Airport            NaN  Australia
# 7169   12043                       Warren Airport            NaN  Australia
# 7170   12044                    West Sale Airport           Sale  Australia
# 7171   12045                 West Wyalong Airport   West Wyalong  Australia
# 7172   12046                        Young Airport            NaN  Australia
#
#      IATA  ICAO   Latitude   Longitude  Altitude Timezone  DST  \
# 3114  ABM  YBAM -10.950800  142.459000        34       10    O
# 3115  ASP  YBAS -23.806700  133.901993      1789      9.5    N
# 3116  BNE  YBBN -27.384199  153.117004        13       10    N
# 3117  OOL  YBCG -28.164400  153.505005        21       10    N
# 3118  CNS  YBCS -16.885799  145.755005        10       10    N
# 3119  CTL  YBCV -26.413300  146.261993      1003       10    O
# 3120  ISA  YBMA -20.663900  139.488998      1121       10    O
# 3121  MCY  YBMC -26.603300  153.091003        15       10    O
# 3122  MKY  YBMK -21.171700  149.179993        19       10    O
# 3123  PPP  YBPN -20.495001  148.552002        82       10    O
# 3124  ROK  YBRK -23.381901  150.475006        34       10    O
# 3125  TSV  YBTL -19.252501  146.764999        18       10    N
# 3126  WEI  YBWP -12.678600  141.925003        63       10    O
# 3127  AVV  YMAV -38.039398  144.468994        35       10    O
# 3128  ABX  YMAY -36.067799  146.957993       539       10    O
# 3129  MEB  YMEN -37.728100  144.901993       282       10    O
# 3131  HBA  YMHB -42.836102  147.509995        13       10    O
# 3132  LST  YMLT -41.545300  147.214005       562       10    O
# 3133  MBW  YMMB -37.975800  145.102005        50       10    O
# 3134  MEL  YMML -37.673302  144.843002       434       10    O
# 3136  ADL  YPAD -34.945000  138.531006        20      9.5    O
# 3138  JAD  YPJT -32.097500  115.880997        99        8    O
# 3139  KTA  YPKA -20.712200  116.773003        29        8    O
# 3140  KGI  YPKG -30.789400  121.461998      1203        8    O
# 3141  KNX  YPKU -15.778100  128.707993       145        8    O
# 3142  LEA  YPLM -22.235600  114.088997        19        8    O
# 3143  PHE  YPPD -20.377800  118.625999        33        8    O
# 3145  PER  YPPH -31.940300  115.967003        67        8    N
# 3146  UMR  YPWR -31.144199  136.817001       548      9.5    O
# 3148  BWU  YSBK -33.924400  150.988007        29       10    O
# ...   ...   ...        ...         ...       ...      ...  ...
# 7143  CWW  YCOR -35.994701  146.356995       469      NaN  NaN
# 7144  CYG  YCRG -36.182800  147.888000       963      NaN  NaN
# 7145  CMD  YCTM -34.623901  148.028000      1110      NaN  NaN
# 7146  DRN  YDBI -28.591700  148.216995       567      NaN  NaN
# 7147  DNQ  YDLQ -35.559399  144.945999       316      NaN  NaN
# 7148  DYA  YDYS -22.622200  148.363998       670      NaN  NaN
# 7149  ECH  YECH -36.157200  144.761993       323      NaN  NaN
# 7150  FRB  YFBS -33.363602  147.934998       760      NaN  NaN
# 7151  GUH  YGDH -30.961100  150.251007       863      NaN  NaN
# 7152  HXX  YHAY -34.531399  144.830002       305      NaN  NaN
# 7153  HTU  YHPN -35.715302  142.360001       256      NaN  NaN
# 7154  KRA  YKER -35.751400  143.938995       254      NaN  NaN
# 7155  KPS  YKMP -31.074400  152.770004        54      NaN  NaN
# 7156  KGY  YKRY -26.580799  151.841003      1492      NaN  NaN
# 7157  TGN  YLTV -38.207199  146.470001       180      NaN  NaN
# 7158  MRG  YMBA -17.069201  145.419006      1560      NaN  NaN
# 7159  RPM  YNGU -14.722800  134.746994        45      NaN  NaN
# 7160  QRM  YNRM -32.214699  148.225006       782      NaN  NaN
# 7161  PPI  YPIR -33.238899  137.994995        40      NaN  NaN
# 7162  SIO  YSMI -40.834999  145.084000        31      NaN  NaN
# 7163  SNB  YSNB -11.422800  130.654007       173      NaN  NaN
# 7164  SWC  YSWL -37.071701  142.740997       807      NaN  NaN
# 7165  TYB  YTIB -29.451099  142.057999       584      NaN  NaN
# 7166  TUM  YTMU -35.262798  148.240997       878      NaN  NaN
# 7167  WGT  YWGT -36.415798  146.307007       504      NaN  NaN
# 7168  WKB  YWKB -36.321098  142.419006       397      NaN  NaN
# 7169  QRR  YWRN -31.733299  147.802994       669      NaN  NaN
# 7170  SXE  YWSL -38.090827  146.965335        72      NaN  NaN
# 7171  WWY  YWWL -33.937199  147.190994       859      NaN  NaN
# 7172  NGA  YYNG -34.255600  148.248001      1267      NaN  NaN
#
#      Tz database time zone     Type       Source
# 3114    Australia/Brisbane  airport  OurAirports
# 3115      Australia/Darwin  airport  OurAirports
# 3116    Australia/Brisbane  airport  OurAirports
# 3117    Australia/Brisbane  airport  OurAirports
# 3118    Australia/Brisbane  airport  OurAirports
# 3119    Australia/Brisbane  airport  OurAirports
# 3120    Australia/Brisbane  airport  OurAirports
# 3121    Australia/Brisbane  airport  OurAirports
# 3122    Australia/Brisbane  airport  OurAirports
# 3123    Australia/Brisbane  airport  OurAirports
# 3124    Australia/Brisbane  airport  OurAirports
# 3125    Australia/Brisbane  airport  OurAirports
# 3126    Australia/Brisbane  airport  OurAirports
# 3127      Australia/Hobart  airport  OurAirports
# 3128      Australia/Sydney  airport  OurAirports
# 3129      Australia/Hobart  airport  OurAirports
# 3131   Australia/Melbourne  airport  OurAirports
# 3132   Australia/Melbourne  airport  OurAirports
# 3133      Australia/Hobart  airport  OurAirports
# 3134      Australia/Hobart  airport  OurAirports
# 3136    Australia/Adelaide  airport  OurAirports
# 3138       Australia/Perth  airport  OurAirports
# 3139       Australia/Perth  airport  OurAirports
# 3140       Australia/Perth  airport  OurAirports
# 3141       Australia/Perth  airport  OurAirports
# 3142       Australia/Perth  airport  OurAirports
# 3143       Australia/Perth  airport  OurAirports
# 3145       Australia/Perth  airport  OurAirports
# 3146    Australia/Adelaide  airport  OurAirports
# 3148      Australia/Sydney  airport  OurAirports
# ...                    ...      ...          ...
# 7143                   NaN  airport  OurAirports
# 7144                   NaN  airport  OurAirports
# 7145                   NaN  airport  OurAirports
# 7146                   NaN  airport  OurAirports
# 7147                   NaN  airport  OurAirports
# 7148                   NaN  airport  OurAirports
# 7149                   NaN  airport  OurAirports
# 7150                   NaN  airport  OurAirports
# 7151                   NaN  airport  OurAirports
# 7152                   NaN  airport  OurAirports
# 7153                   NaN  airport  OurAirports
# 7154                   NaN  airport  OurAirports
# 7155                   NaN  airport  OurAirports
# 7156                   NaN  airport  OurAirports
# 7157                   NaN  airport  OurAirports
# 7158                   NaN  airport  OurAirports
# 7159                   NaN  airport  OurAirports
# 7160                   NaN  airport  OurAirports
# 7161                   NaN  airport  OurAirports
# 7162                   NaN  airport  OurAirports
# 7163                   NaN  airport  OurAirports
# 7164                   NaN  airport  OurAirports
# 7165                   NaN  airport  OurAirports
# 7166                   NaN  airport  OurAirports
# 7167                   NaN  airport  OurAirports
# 7168                   NaN  airport  OurAirports
# 7169                   NaN  airport  OurAirports
# 7170                   NaN  airport  OurAirports
# 7171                   NaN  airport  OurAirports
# 7172                   NaN  airport  OurAirports
#
# [260 rows x 14 columns]

# %%
route = pd.read_csv('routes.csv',names = ['Airline', 'AirlineID', 'SourceAirport', 'SourceAirportID', 'DestinationAirport', 'DestinationAirportID', 'Codeshare', 'Stops', 'Equipment'])
route1=route.replace('\\N',NA)

# %%
route_aus=route1[(route1['SourceAirport'].isin(air_aus['IATA']))&(-route1['DestinationAirport'].isin(air_aus['IATA']))]
route_aus
# Out:
#       Airline AirlineID SourceAirport SourceAirportID DestinationAirport  \
# 382        3K      3021           DRW            3999                SIN
# 393        3K      3021           PER            3351                SIN
# 837        3U      4608           MEL            3339                CTU
# 886        3U      4608           SYD            3361                CKG
# 4777       AA        24           BNE            3320                AKL
# 4781       AA        24           BNE            3320                LAX
# 5976       AA        24           MEL            3339                LAX
# 6875       AA        24           SYD            3361                AKL
# 6879       AA        24           SYD            3361                CHC
# 6881       AA        24           SYD            3361                DFW
# 6883       AA        24           SYD            3361                HNL
# 6884       AA        24           SYD            3361                LAX
# 7070       AB       214           BNE            3320                SIN
# 8054       AC       330           SYD            3361                YVR
# 10596      AI       218           MEL            3339                DEL
# 10643      AI       218           SYD            3361                DEL
# 12601      AY      2350           BNE            3320                HKG
# 12616      AY      2350           CNS            3322                HKG
# 12821      AY      2350           MEL            3339                HKG
# 12871      AY      2350           SYD            3361                HKG
# 13510      AZ       596           MEL            3339                AUH
# 13698      AZ       596           SYD            3361                AUH
# 14470      BA      1355           CNS            3322                HKG
# 14906      BA      1355           SYD            3361                SIN
# 15379      BI      4255           MEL            3339                BWN
# 15610      BR      2091           BNE            3320                TPE
# 16587      CA       751           MEL            3339                PVG
# 16916      CA       751           SYD            3361                PEK
# 16917      CA       751           SYD            3361                PVG
# 17307      CG      1308           BNE            3320                POM
# ...       ...       ...           ...             ...                ...
# 61103      VA      5360           MEL            3339                AUH
# 61107      VA      5360           MEL            3339                CHC
# 61109      VA      5360           MEL            3339                DPS
# 61114      VA      5360           MEL            3339                LAX
# 61118      VA      5360           MEL            3339                NAN
# 61122      VA      5360           MEL            3339                SIN
# 61124      VA      5360           MEL            3339                WLG
# 61140      VA      5360           OOL            3321                AKL
# 61142      VA      5360           OOL            3321                CHC
# 61147      VA      5360           PER            3351                AKL
# 61153      VA      5360           PER            3351                DPS
# 61157      VA      5360           PER            3351                HKT
# 61166      VA      5360           PER            3351                SIN
# 61168      VA      5360           PER            3351                XCH
# 61172      VA      5360           PHE            3349                DPS
# 61199      VA      5360           SYD            3361                AKL
# 61200      VA      5360           SYD            3361                APW
# 61201      VA      5360           SYD            3361                AUH
# 61207      VA      5360           SYD            3361                CHC
# 61209      VA      5360           SYD            3361                DPS
# 61212      VA      5360           SYD            3361                HKG
# 61213      VA      5360           SYD            3361                HNL
# 61216      VA      5360           SYD            3361                LAX
# 61221      VA      5360           SYD            3361                NAN
# 61225      VA      5360           SYD            3361                SIN
# 61226      VA      5360           SYD            3361                TBU
# 61228      VA      5360           SYD            3361                WLG
# 61503      VN      5309           MEL            3339                SGN
# 61578      VN      5309           SYD            3361                SGN
# 61838      VS      5347           SYD            3361                HKG
#
#       DestinationAirportID Codeshare  Stops        Equipment
# 382                   3316       NaN      0              320
# 393                   3316       NaN      0              320
# 837                   3395       NaN      0              330
# 886                   3393       NaN      0              330
# 4777                  2006         Y      0              737
# 4781                  3484         Y      0              744
# 5976                  3484         Y      0              380
# 6875                  2006         Y      0              737
# 6879                  2009         Y      0              737
# 6881                  3670         Y      0              744
# 6883                  3728         Y      0              763
# 6884                  3484         Y      0          744 380
# 7070                  3316         Y      0              332
# 8054                   156       NaN      0              77L
# 10596                 3093       NaN      0              788
# 10643                 3093       NaN      0              788
# 12601                 3077       NaN      0              333
# 12616                 3077         Y      0              333
# 12821                 3077       NaN      0              333
# 12871                 3077         Y      0          388 744
# 13510                 2179         Y      0              77W
# 13698                 2179         Y      0          77W 346
# 14470                 3077         Y      0              333
# 14906                 3316       NaN      0              777
# 15379                 3272       NaN      0              787
# 15610                 2276       NaN      0              332
# 16587                 3406       NaN      0              330
# 16916                 3364       NaN      0              330
# 16917                 3406       NaN      0              330
# 17307                    5       NaN      0              737
# ...                    ...       ...    ...              ...
# 61103                 2179         Y      0              77W
# 61107                 2009       NaN      0          320 73H
# 61109                 3940       NaN      0              73H
# 61114                 3484       NaN      0              77W
# 61118                 1960         Y      0              73H
# 61122                 3316         Y      0  77W 773 388 333
# 61124                 2042       NaN      0              320
# 61140                 2006         Y      0          73H 320
# 61142                 2009       NaN      0              320
# 61147                 2006         Y      0              772
# 61153                 3940         Y      0              73H
# 61157                 3179         Y      0              73H
# 61166                 3316       NaN      0              772
# 61168                 3353       NaN      0          E90 73H
# 61172                 3940       NaN      0              100
# 61199                 2006         Y      0  763 73H 320 772
# 61200                 1969         Y      0              73H
# 61201                 2179       NaN      0              77W
# 61207                 2009       NaN      0              320
# 61209                 3940         Y      0              73H
# 61212                 3077         Y      0              346
# 61213                 3728         Y      0              332
# 61216                 3484       NaN      0              77W
# 61221                 1960         Y      0              73H
# 61225                 3316         Y      0      773 388 772
# 61226                 1963         Y      0              73H
# 61228                 2042       NaN      0              320
# 61503                 3205       NaN      0              330
# 61578                 3205       NaN      0              330
# 61838                 3077       NaN      0              346
#
# [337 rows x 9 columns]

# %%
source_airport = pd.DataFrame(route_aus.groupby('SourceAirport').size())
destination_airport = pd.DataFrame(route_aus.groupby('DestinationAirport').size())
#merged = pd.merge(source_airport, destination_airport, left_index=True, right_index=True)
#merged
#destination_airport

pivot_table=pd.DataFrame(source_airport, destination_airport)
pivot_table
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\lib\pretty.py in pretty(self, obj)
#     398                         if cls is not object \
#     399                                 and callable(cls.__dict__.get('__repr__')):
# --> 400                             return _repr_pprint(obj, self, cycle)
#     401
#     402             return _default_pprint(obj, self, cycle)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\lib\pretty.py in _repr_pprint(obj, p, cycle)
#     693     """A pprint that just redirects to the normal repr function."""
#     694     # Find newlines and replace them with p.break_()
# --> 695     output = repr(obj)
#     696     for idx,output_line in enumerate(output.splitlines()):
#     697         if idx:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in __repr__(self)
#      80         Yields Bytestring in Py2, Unicode String in py3.
#      81         """
# ---> 82         return str(self)
#      83
#      84
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\base.py in __str__(self)
#      59
#      60         if compat.PY3:
# ---> 61             return self.__unicode__()
#      62         return self.__bytes__()
#      63
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __unicode__(self)
#     661             width = None
#     662         self.to_string(buf=buf, max_rows=max_rows, max_cols=max_cols,
# --> 663                        line_width=width, show_dimensions=show_dimensions)
#     664
#     665         return buf.getvalue()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in to_string(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, line_width, max_rows, max_cols, show_dimensions)
#    1969                                            max_cols=max_cols,
#    1970                                            show_dimensions=show_dimensions)
# -> 1971         formatter.to_string()
#    1972
#    1973         if buf is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_string(self)
#     609         else:
#     610
# --> 611             strcols = self._to_str_columns()
#     612             if self.line_width is None:  # no need to wrap around just print
#     613                 # the whole frame
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in _to_str_columns(self)
#     518         # may include levels names also
#     519
# --> 520         str_index = self._get_formatted_index(frame)
#     521
#     522         if not is_list_like(self.header) and not self.header:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in _get_formatted_index(self, frame)
#     826                                      names=show_index_names, formatter=fmt)
#     827         else:
# --> 828             fmt_index = [index.format(name=show_index_names, formatter=fmt)]
#     829         fmt_index = [tuple(_make_fixed_width(list(x), justify='left',
#     830                                              minimum=(self.col_space or 0),
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in format(self, name, formatter, **kwargs)
#    2378             return header + list(self.map(formatter))
#    2379
# -> 2380         return self._format_with_header(header, **kwargs)
#    2381
#    2382     def _format_with_header(self, header, na_rep='NaN', **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_with_header(self, header, na_rep, **kwargs)
#    2403
#    2404         else:
# -> 2405             result = _trim_front(format_array(values, None, justify='left'))
#    2406         return header + result
#    2407
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#     894                         space=space, justify=justify, decimal=decimal)
#     895
# --> 896     return fmt_obj.get_result()
#     897
#     898
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#     914
#     915     def get_result(self):
# --> 916         fmt_values = self._format_strings()
#     917         return _make_fixed_width(fmt_values, self.justify)
#     918
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1109     def _format_strings(self):
#    1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#    1113
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in <listcomp>(.0)
#    1109     def _format_strings(self):
#    1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#    1113
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1108
#    1109     def _format_strings(self):
# -> 1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
#    1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     694
#     695             return self.to_html(max_rows=max_rows, max_cols=max_cols,
# --> 696                                 show_dimensions=show_dimensions, notebook=True)
#     697         else:
#     698             return None
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in to_html(self, buf, columns, col_space, header, index, na_rep, formatters, float_format, sparsify, index_names, justify, bold_rows, classes, escape, max_rows, max_cols, show_dimensions, notebook, decimal, border, table_id)
#    2035                                            decimal=decimal, table_id=table_id)
#    2036         # TODO: a generic formatter wld b in DataFrameFormatter
# -> 2037         formatter.to_html(classes=classes, notebook=notebook, border=border)
#    2038
#    2039         if buf is None:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     753                                       table_id=self.table_id)
#     754         if hasattr(self.buf, 'write'):
# --> 755             html_renderer.write_result(self.buf)
#     756         elif isinstance(self.buf, compat.string_types):
#     757             with open(self.buf, 'w') as f:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\html.py in write_result(self, buf)
#     178         indent += self.indent_delta
#     179         indent = self._write_header(indent)
# --> 180         indent = self._write_body(indent)
#     181
#     182         self.write('</table>', indent)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_body(self, indent)
#     341                 self._write_hierarchical_rows(fmt_values, indent)
#     342             else:
# --> 343                 self._write_regular_rows(fmt_values, indent)
#     344         else:
#     345             for i in range(min(len(self.frame), self.max_rows)):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\html.py in _write_regular_rows(self, fmt_values, indent)
#     363             index_values = self.fmt.tr_frame.index.map(fmt)
#     364         else:
# --> 365             index_values = self.fmt.tr_frame.index.format()
#     366
#     367         row = []
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in format(self, name, formatter, **kwargs)
#    2378             return header + list(self.map(formatter))
#    2379
# -> 2380         return self._format_with_header(header, **kwargs)
#    2381
#    2382     def _format_with_header(self, header, na_rep='NaN', **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _format_with_header(self, header, na_rep, **kwargs)
#    2403
#    2404         else:
# -> 2405             result = _trim_front(format_array(values, None, justify='left'))
#    2406         return header + result
#    2407
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in format_array(values, formatter, float_format, na_rep, digits, space, justify, decimal)
#     894                         space=space, justify=justify, decimal=decimal)
#     895
# --> 896     return fmt_obj.get_result()
#     897
#     898
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in get_result(self)
#     914
#     915     def get_result(self):
# --> 916         fmt_values = self._format_strings()
#     917         return _make_fixed_width(fmt_values, self.justify)
#     918
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in _format_strings(self)
#    1109     def _format_strings(self):
#    1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#    1113
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in <listcomp>(.0)
#    1109     def _format_strings(self):
#    1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
# -> 1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#    1113
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\formats\format.py in <lambda>(x)
#    1108
#    1109     def _format_strings(self):
# -> 1110         formatter = self.formatter or (lambda x: '{x: d}'.format(x=x))
#    1111         fmt_values = [formatter(x) for x in self.values]
#    1112         return fmt_values
#
# TypeError: unsupported format string passed to numpy.ndarray.__format__

# %%
merged['Fly'] = merged['0_x'] + merged['0_y']
del merged['0_x']

# %%
del merged['0_y']

# %%
merged.index
# Out:
# Index(['AAE', 'AAL', 'AAQ', 'AAR', 'ABA', 'ABJ', 'ABV', 'ABZ', 'ACC', 'ACE',
#        ...
#        'YVR', 'YYC', 'YYT', 'YYZ', 'ZAD', 'ZAG', 'ZAZ', 'ZQW', 'ZRH', 'ZTH'],
#       dtype='object', length=1008)

# %%
air_eu=airport.set_index('IATA')

# %%
pivot_table= pd.DataFrame(air_eu, columns = ['Country', 'Name', 'Fly'])
pivot_table = pivot_table.sort_values(by=['Country'], ascending=True)
pivot=pd.merge(pivot_table, merged, left_index=True, right_index=True)
del pivot['Fly_x']
pivot
# Out:
#             Country                                               Name  Fly_y
# AAE         Algeria                                     Annaba Airport     14
# AAL         Denmark                                    Aalborg Airport     41
# AAQ          Russia                            Anapa Vityazevo Airport      6
# AAR         Denmark                                     Aarhus Airport     16
# ABA          Russia                                     Abakan Airport      8
# ABJ   Cote d'Ivoire                                 Port Bouet Airport     14
# ABV         Nigeria               Nnamdi Azikiwe International Airport     10
# ABZ  United Kingdom                              Aberdeen Dyce Airport     82
# ACC           Ghana                       Kotoka International Airport     15
# ACE           Spain                                  Lanzarote Airport    233
# ACH     Switzerland                       St Gallen Altenrhein Airport      4
# ACI        Guernsey                                   Alderney Airport      4
# ADA          Turkey                                      Adana Airport     34
# ADB          Turkey               Adnan Menderes International Airport    133
# ADD        Ethiopia             Addis Ababa Bole International Airport     14
# ADF          Turkey                                   Adıyaman Airport      4
# AER          Russia                        Sochi International Airport     52
# AES          Norway                                    Ålesund Airport     26
# AEY         Iceland                                   Akureyri Airport      2
# AGA         Morocco                                 Al Massira Airport     49
# AGB         Germany                                   Augsburg Airport      2
# AGF          France                            Agen-La Garenne Airport      4
# AGH          Sweden                      Ängelholm-Helsingborg Airport      6
# AGM       Greenland                                  Tasiilaq Heliport     10
# AGP           Spain                                     Málaga Airport    410
# AHO           Italy                           Alghero-Fertilia Airport     62
# AJA          France                 Ajaccio-Napoléon Bonaparte Airport     78
# AJI          Turkey                                       Ağrı Airport      4
# AJR          Sweden                                 Arvidsjaur Airport      4
# AKX      Kazakhstan                                     Aktobe Airport      4
# ..              ...                                                ...    ...
# WAT         Ireland                                  Waterford Airport      4
# WAW          Poland                              Warsaw Chopin Airport    240
# WDH         Namibia                 Hosea Kutako International Airport      2
# WIC  United Kingdom                                       Wick Airport      4
# WMI          Poland                                     Modlin Airport     52
# WRO          Poland                         Copernicus Wrocław Airport     66
# WRY  United Kingdom                                    Westray Airport      4
# WUH           China                 Wuhan Tianhe International Airport      2
# XCR          France                             Châlons-Vatry Air Base      4
# XFW         Germany                       Hamburg-Finkenwerder Airport      2
# XIY           China               Xi'an Xianyang International Airport      2
# XMN           China                 Xiamen Gaoqi International Airport      4
# XRY           Spain                                      Jerez Airport     43
# YEG          Canada                     Edmonton International Airport      6
# YHZ          Canada          Halifax / Stanfield International Airport      6
# YKS          Russia                                    Yakutsk Airport     76
# YNB    Saudi Arabia           Prince Abdulmohsin Bin Abdulaziz Airport      2
# YOW          Canada     Ottawa Macdonald-Cartier International Airport      8
# YQB          Canada           Quebec Jean Lesage International Airport      2
# YUL          Canada  Montreal / Pierre Elliott Trudeau Internationa...     82
# YVR          Canada                    Vancouver International Airport     30
# YYC          Canada                      Calgary International Airport     30
# YYT          Canada                   St. John's International Airport      4
# YYZ          Canada            Lester B. Pearson International Airport    119
# ZAD         Croatia                                    Zemunik Airport     52
# ZAG         Croatia                                     Zagreb Airport     85
# ZAZ           Spain                                  Zaragoza Air Base     16
# ZQW         Germany                                Zweibrücken Airport     11
# ZRH     Switzerland                                     Zürich Airport    494
# ZTH          Greece                          Dionysios Solomos Airport     33
#
# [955 rows x 3 columns]

# %%
pivot = pivot.rename(columns = {'Fly_y': 'Fly'})
pivot
# Out:
#             Country                                               Name  Fly
# AAE         Algeria                                     Annaba Airport   14
# AAL         Denmark                                    Aalborg Airport   41
# AAQ          Russia                            Anapa Vityazevo Airport    6
# AAR         Denmark                                     Aarhus Airport   16
# ABA          Russia                                     Abakan Airport    8
# ABJ   Cote d'Ivoire                                 Port Bouet Airport   14
# ABV         Nigeria               Nnamdi Azikiwe International Airport   10
# ABZ  United Kingdom                              Aberdeen Dyce Airport   82
# ACC           Ghana                       Kotoka International Airport   15
# ACE           Spain                                  Lanzarote Airport  233
# ACH     Switzerland                       St Gallen Altenrhein Airport    4
# ACI        Guernsey                                   Alderney Airport    4
# ADA          Turkey                                      Adana Airport   34
# ADB          Turkey               Adnan Menderes International Airport  133
# ADD        Ethiopia             Addis Ababa Bole International Airport   14
# ADF          Turkey                                   Adıyaman Airport    4
# AER          Russia                        Sochi International Airport   52
# AES          Norway                                    Ålesund Airport   26
# AEY         Iceland                                   Akureyri Airport    2
# AGA         Morocco                                 Al Massira Airport   49
# AGB         Germany                                   Augsburg Airport    2
# AGF          France                            Agen-La Garenne Airport    4
# AGH          Sweden                      Ängelholm-Helsingborg Airport    6
# AGM       Greenland                                  Tasiilaq Heliport   10
# AGP           Spain                                     Málaga Airport  410
# AHO           Italy                           Alghero-Fertilia Airport   62
# AJA          France                 Ajaccio-Napoléon Bonaparte Airport   78
# AJI          Turkey                                       Ağrı Airport    4
# AJR          Sweden                                 Arvidsjaur Airport    4
# AKX      Kazakhstan                                     Aktobe Airport    4
# ..              ...                                                ...  ...
# WAT         Ireland                                  Waterford Airport    4
# WAW          Poland                              Warsaw Chopin Airport  240
# WDH         Namibia                 Hosea Kutako International Airport    2
# WIC  United Kingdom                                       Wick Airport    4
# WMI          Poland                                     Modlin Airport   52
# WRO          Poland                         Copernicus Wrocław Airport   66
# WRY  United Kingdom                                    Westray Airport    4
# WUH           China                 Wuhan Tianhe International Airport    2
# XCR          France                             Châlons-Vatry Air Base    4
# XFW         Germany                       Hamburg-Finkenwerder Airport    2
# XIY           China               Xi'an Xianyang International Airport    2
# XMN           China                 Xiamen Gaoqi International Airport    4
# XRY           Spain                                      Jerez Airport   43
# YEG          Canada                     Edmonton International Airport    6
# YHZ          Canada          Halifax / Stanfield International Airport    6
# YKS          Russia                                    Yakutsk Airport   76
# YNB    Saudi Arabia           Prince Abdulmohsin Bin Abdulaziz Airport    2
# YOW          Canada     Ottawa Macdonald-Cartier International Airport    8
# YQB          Canada           Quebec Jean Lesage International Airport    2
# YUL          Canada  Montreal / Pierre Elliott Trudeau Internationa...   82
# YVR          Canada                    Vancouver International Airport   30
# YYC          Canada                      Calgary International Airport   30
# YYT          Canada                   St. John's International Airport    4
# YYZ          Canada            Lester B. Pearson International Airport  119
# ZAD         Croatia                                    Zemunik Airport   52
# ZAG         Croatia                                     Zagreb Airport   85
# ZAZ           Spain                                  Zaragoza Air Base   16
# ZQW         Germany                                Zweibrücken Airport   11
# ZRH     Switzerland                                     Zürich Airport  494
# ZTH          Greece                          Dionysios Solomos Airport   33
#
# [955 rows x 3 columns]

# %%
pivot1=pivot[pivot['Country'].isin(Europe)]
pivot1
# Out:
#             Country                                    Name  Fly
# AAL         Denmark                         Aalborg Airport   41
# AAQ          Russia                 Anapa Vityazevo Airport    6
# AAR         Denmark                          Aarhus Airport   16
# ABA          Russia                          Abakan Airport    8
# ABZ  United Kingdom                   Aberdeen Dyce Airport   82
# ACE           Spain                       Lanzarote Airport  233
# ACH     Switzerland            St Gallen Altenrhein Airport    4
# ACI        Guernsey                        Alderney Airport    4
# ADA          Turkey                           Adana Airport   34
# ADB          Turkey    Adnan Menderes International Airport  133
# ADF          Turkey                        Adıyaman Airport    4
# AER          Russia             Sochi International Airport   52
# AES          Norway                         Ålesund Airport   26
# AEY         Iceland                        Akureyri Airport    2
# AGB         Germany                        Augsburg Airport    2
# AGF          France                 Agen-La Garenne Airport    4
# AGH          Sweden           Ängelholm-Helsingborg Airport    6
# AGM       Greenland                       Tasiilaq Heliport   10
# AGP           Spain                          Málaga Airport  410
# AHO           Italy                Alghero-Fertilia Airport   62
# AJA          France      Ajaccio-Napoléon Bonaparte Airport   78
# AJI          Turkey                            Ağrı Airport    4
# AJR          Sweden                      Arvidsjaur Airport    4
# ALC           Spain          Alicante International Airport  314
# ALF          Norway                            Alta Airport   20
# AMS     Netherlands              Amsterdam Airport Schiphol  903
# ANG          France       Angoulême-Brie-Champniers Airport    2
# ANR         Belgium  Antwerp International Airport (Deurne)    4
# ANX          Norway                          Andøya Airport    7
# AOE          Turkey                         Anadolu Airport    2
# ..              ...                                     ...  ...
# VIN         Ukraine          Vinnytsia/Gavyryshivka Airport    2
# VKO          Russia           Vnukovo International Airport  171
# VKT          Russia                         Vorkuta Airport    4
# VLC           Spain                        Valencia Airport  163
# VLL           Spain                      Valladolid Airport    7
# VLY  United Kingdom                        Anglesey Airport    2
# VNO       Lithuania           Vilnius International Airport  116
# VOG          Russia         Volgograd International Airport   20
# VOL          Greece                   Nea Anchialos Airport   10
# VOZ          Russia          Voronezh International Airport   16
# VRN           Italy              Verona Villafranca Airport   77
# VST          Sweden              Stockholm Västerås Airport    6
# VVO          Russia       Vladivostok International Airport   52
# VXO          Sweden                 Växjö Kronoberg Airport   15
# WAT         Ireland                       Waterford Airport    4
# WAW          Poland                   Warsaw Chopin Airport  240
# WIC  United Kingdom                            Wick Airport    4
# WMI          Poland                          Modlin Airport   52
# WRO          Poland              Copernicus Wrocław Airport   66
# WRY  United Kingdom                         Westray Airport    4
# XCR          France                  Châlons-Vatry Air Base    4
# XFW         Germany            Hamburg-Finkenwerder Airport    2
# XRY           Spain                           Jerez Airport   43
# YKS          Russia                         Yakutsk Airport   76
# ZAD         Croatia                         Zemunik Airport   52
# ZAG         Croatia                          Zagreb Airport   85
# ZAZ           Spain                       Zaragoza Air Base   16
# ZQW         Germany                     Zweibrücken Airport   11
# ZRH     Switzerland                          Zürich Airport  494
# ZTH          Greece               Dionysios Solomos Airport   33
#
# [664 rows x 3 columns]

# %%
pivot1 = pivot1.sort_values(by=['Country', 'Fly'], ascending=[True,False])
pivot1
# Out:
#                     Country                                        Name  Fly
# TIA                 Albania  Tirana International Airport Mother Teresa   72
# VIE                 Austria                Vienna International Airport  616
# SZG                 Austria                            Salzburg Airport   69
# GRZ                 Austria                                Graz Airport   38
# LNZ                 Austria                      Linz Hörsching Airport   23
# INN                 Austria                           Innsbruck Airport   16
# KLU                 Austria                          Klagenfurt Airport   14
# MSQ                 Belarus                      Minsk National Airport  108
# BRU                 Belgium                            Brussels Airport  631
# CRL                 Belgium            Brussels South Charleroi Airport  168
# LGG                 Belgium                               Liège Airport   17
# ANR                 Belgium      Antwerp International Airport (Deurne)    4
# OST                 Belgium         Ostend-Bruges International Airport    2
# SJJ  Bosnia and Herzegovina              Sarajevo International Airport   32
# BNX  Bosnia and Herzegovina            Banja Luka International Airport    6
# OMO  Bosnia and Herzegovina                Mostar International Airport    2
# SOF                Bulgaria                               Sofia Airport  132
# BOJ                Bulgaria                              Burgas Airport   24
# VAR                Bulgaria                               Varna Airport   18
# PDV                Bulgaria               Plovdiv International Airport    4
# DBV                 Croatia                           Dubrovnik Airport  121
# SPU                 Croatia                               Split Airport   97
# ZAG                 Croatia                              Zagreb Airport   85
# ZAD                 Croatia                             Zemunik Airport   52
# PUY                 Croatia                                Pula Airport   30
# RJK                 Croatia                              Rijeka Airport   14
# OSI                 Croatia                              Osijek Airport    8
# BWK                 Croatia                                 Bol Airport    2
# LCA                  Cyprus               Larnaca International Airport  190
# PFO                  Cyprus                Paphos International Airport   85
# ..                      ...                                         ...  ...
# SEN          United Kingdom                            Southend Airport   28
# KOI          United Kingdom                            Kirkwall Airport   22
# INV          United Kingdom                           Inverness Airport   21
# NWI          United Kingdom               Norwich International Airport   20
# BLK          United Kingdom             Blackpool International Airport   18
# DSA          United Kingdom      Robin Hood Doncaster Sheffield Airport   18
# NQY          United Kingdom                    Newquay Cornwall Airport   12
# HUY          United Kingdom                          Humberside Airport   10
# LDY          United Kingdom                       City of Derry Airport   10
# LSI          United Kingdom                            Sumburgh Airport   10
# SYY          United Kingdom                           Stornoway Airport   10
# ISC          United Kingdom                          St. Mary's Airport    6
# MME          United Kingdom                  Durham Tees Valley Airport    6
# NRL          United Kingdom                     North Ronaldsay Airport    6
# PPW          United Kingdom                        Papa Westray Airport    6
# NDY          United Kingdom                              Sanday Airport    5
# BEB          United Kingdom                           Benbecula Airport    4
# CEG          United Kingdom                            Hawarden Airport    4
# SOY          United Kingdom                            Stronsay Airport    4
# WIC          United Kingdom                                Wick Airport    4
# WRY          United Kingdom                             Westray Airport    4
# EOI          United Kingdom                                Eday Airport    3
# BRR          United Kingdom                               Barra Airport    2
# CAL          United Kingdom                         Campbeltown Airport    2
# DND          United Kingdom                              Dundee Airport    2
# GLO          United Kingdom                     Gloucestershire Airport    2
# ILY          United Kingdom                               Islay Airport    2
# LEQ          United Kingdom                          Land's End Airport    2
# TRE          United Kingdom                               Tiree Airport    2
# VLY          United Kingdom                            Anglesey Airport    2
#
# [664 rows x 3 columns]

# %%
ser = pivot1.set_index(['Country', 'Name'])
ser = ser.groupby('Country').head(3)
ser
# Out:
#                                                                     Fly
# Country                Name
# Albania                Tirana International Airport Mother Teresa    72
# Austria                Vienna International Airport                 616
#                        Salzburg Airport                              69
#                        Graz Airport                                  38
# Belarus                Minsk National Airport                       108
# Belgium                Brussels Airport                             631
#                        Brussels South Charleroi Airport             168
#                        Liège Airport                                 17
# Bosnia and Herzegovina Sarajevo International Airport                32
#                        Banja Luka International Airport               6
#                        Mostar International Airport                   2
# Bulgaria               Sofia Airport                                132
#                        Burgas Airport                                24
#                        Varna Airport                                 18
# Croatia                Dubrovnik Airport                            121
#                        Split Airport                                 97
#                        Zagreb Airport                                85
# Cyprus                 Larnaca International Airport                190
#                        Paphos International Airport                  85
#                        Ercan International Airport                   28
# Czech Republic         Václav Havel Airport Prague                  361
#                        Karlovy Vary International Airport            10
#                        Ostrava Leos Janáček Airport                   8
# Denmark                Copenhagen Kastrup Airport                   457
#                        Billund Airport                               94
#                        Aalborg Airport                               41
# Estonia                Lennart Meri Tallinn Airport                  76
#                        Tartu Airport                                  4
#                        Kuressaare Airport                             2
# Faroe Islands          Vagar Airport                                  8
# ...                                                                 ...
# Portugal               Francisco de Sá Carneiro Airport             202
# Romania                Henri Coandă International Airport           227
#                        Cluj-Napoca International Airport             42
#                        Timişoara Traian Vuia Airport                 26
# Russia                 Domodedovo International Airport             649
#                        Sheremetyevo International Airport           397
#                        Pulkovo Airport                              368
# Serbia                 Belgrade Nikola Tesla Airport                171
#                        Priština International Airport                42
# Slovakia               M. R. Štefánik Airport                        40
#                        Košice Airport                                11
# Slovenia               Ljubljana Jože Pučnik Airport                 66
# Spain                  Barcelona International Airport              783
#                        Adolfo Suárez Madrid–Barajas Airport         661
#                        Palma De Mallorca Airport                    548
# Sweden                 Stockholm-Arlanda Airport                    439
#                        Gothenburg-Landvetter Airport                106
#                        Stockholm Skavsta Airport                     62
# Switzerland            Zürich Airport                               494
#                        Geneva Cointrin International Airport        329
#                        Bern Belp Airport                             24
# Turkey                 Atatürk International Airport                719
#                        Sabiha Gökçen International Airport          290
#                        Antalya International Airport                253
# Ukraine                Boryspil International Airport               202
#                        Kiev Zhuliany International Airport           44
#                        Odessa International Airport                  37
# United Kingdom         London Heathrow Airport                     1051
#                        London Gatwick Airport                       708
#                        Manchester Airport                           627
#
# [112 rows x 1 columns]

# %%
done = ser['Fly']
done
# Out:
# Country                 Name
# Albania                 Tirana International Airport Mother Teresa      72
# Austria                 Vienna International Airport                   616
#                         Salzburg Airport                                69
#                         Graz Airport                                    38
# Belarus                 Minsk National Airport                         108
# Belgium                 Brussels Airport                               631
#                         Brussels South Charleroi Airport               168
#                         Liège Airport                                   17
# Bosnia and Herzegovina  Sarajevo International Airport                  32
#                         Banja Luka International Airport                 6
#                         Mostar International Airport                     2
# Bulgaria                Sofia Airport                                  132
#                         Burgas Airport                                  24
#                         Varna Airport                                   18
# Croatia                 Dubrovnik Airport                              121
#                         Split Airport                                   97
#                         Zagreb Airport                                  85
# Cyprus                  Larnaca International Airport                  190
#                         Paphos International Airport                    85
#                         Ercan International Airport                     28
# Czech Republic          Václav Havel Airport Prague                    361
#                         Karlovy Vary International Airport              10
#                         Ostrava Leos Janáček Airport                     8
# Denmark                 Copenhagen Kastrup Airport                     457
#                         Billund Airport                                 94
#                         Aalborg Airport                                 41
# Estonia                 Lennart Meri Tallinn Airport                    76
#                         Tartu Airport                                    4
#                         Kuressaare Airport                               2
# Faroe Islands           Vagar Airport                                    8
#                                                                       ...
# Portugal                Francisco de Sá Carneiro Airport               202
# Romania                 Henri Coandă International Airport             227
#                         Cluj-Napoca International Airport               42
#                         Timişoara Traian Vuia Airport                   26
# Russia                  Domodedovo International Airport               649
#                         Sheremetyevo International Airport             397
#                         Pulkovo Airport                                368
# Serbia                  Belgrade Nikola Tesla Airport                  171
#                         Priština International Airport                  42
# Slovakia                M. R. Štefánik Airport                          40
#                         Košice Airport                                  11
# Slovenia                Ljubljana Jože Pučnik Airport                   66
# Spain                   Barcelona International Airport                783
#                         Adolfo Suárez Madrid–Barajas Airport           661
#                         Palma De Mallorca Airport                      548
# Sweden                  Stockholm-Arlanda Airport                      439
#                         Gothenburg-Landvetter Airport                  106
#                         Stockholm Skavsta Airport                       62
# Switzerland             Zürich Airport                                 494
#                         Geneva Cointrin International Airport          329
#                         Bern Belp Airport                               24
# Turkey                  Atatürk International Airport                  719
#                         Sabiha Gökçen International Airport            290
#                         Antalya International Airport                  253
# Ukraine                 Boryspil International Airport                 202
#                         Kiev Zhuliany International Airport             44
#                         Odessa International Airport                    37
# United Kingdom          London Heathrow Airport                       1051
#                         London Gatwick Airport                         708
#                         Manchester Airport                             627
# Name: Fly, Length: 112, dtype: int64
