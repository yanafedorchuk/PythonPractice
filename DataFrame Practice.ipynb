# %%
import numpy as np
import pandas as pd
from numpy import nan as NA

# %%
airport = pd.read_csv('airports.csv', names = ['Aiport', 'Name', 'City', 'Country', 'IATA', 'ICAO', 'Latitude', 'Longitude', 'Altitude', 'Timezone', 'DST', 'Tz database time zone', 'Type', 'Source'])
airport
airport.count()
# Out:
#       Aiport                                         Name                City  \
# 0          1                               Goroka Airport              Goroka
# 1          2                               Madang Airport              Madang
# 2          3                 Mount Hagen Kagamuga Airport         Mount Hagen
# 3          4                               Nadzab Airport              Nadzab
# 4          5  Port Moresby Jacksons International Airport        Port Moresby
# 5          6                  Wewak International Airport               Wewak
# 6          7                           Narsarsuaq Airport        Narssarssuaq
# 7          8                      Godthaab / Nuuk Airport            Godthaab
# 8          9                        Kangerlussuaq Airport         Sondrestrom
# 9         10                               Thule Air Base               Thule
# 10        11                             Akureyri Airport            Akureyri
# ...

# %%
airport.count()
sortbycountry = airport['Country'].sort_values()
sortbycountry
# Out:
# 1982    Afghanistan
# 1978    Afghanistan
# 1979    Afghanistan
# 1980    Afghanistan
# 6284    Afghanistan
# 1981    Afghanistan
# 1983    Afghanistan
# 6622    Afghanistan
# 4563    Afghanistan
# 1984    Afghanistan
# 1985    Afghanistan
# 1986    Afghanistan
# 5583    Afghanistan
# 5584    Afghanistan
# 5585    Afghanistan
# 5291    Afghanistan
# 5785    Afghanistan
# 5919    Afghanistan
# 5932    Afghanistan
# 6254    Afghanistan
# 6999        Albania
# 7001        Albania
# 7000        Albania
# 1159        Albania
# 7002        Albania
# 238         Algeria
# 219         Algeria
# 220         Algeria
# 239         Algeria
# 240         Algeria
#            ...
# 3746          Yemen
# 3754          Yemen
# 4594          Yemen
# 889          Zambia
# 888          Zambia
# 887          Zambia
# 886          Zambia
# 890          Zambia
# 4290         Zambia
# 891          Zambia
# 6576         Zambia
# 4291         Zambia
# 6935         Zambia
# 5761         Zambia
# ...

# %%
sort_city1=airport[airport['City'].isnull()]
sort_city1.count()
# Out:
# Aiport                   44
# Name                     44
# City                      0
# Country                  44
# IATA                     44
# ICAO                     44
# Latitude                 44
# Longitude                44
# Altitude                 44
# Timezone                 44
# DST                      44
# Tz database time zone    44
# Type                     44
# Source                   44
# dtype: int64

# %%
ar=airport['Country'].unique()
ar1=pd.DataFrame(ar)
ar1
# Out:
#                            0
# 0           Papua New Guinea
# 1                  Greenland
# 2                    Iceland
# 3                     Canada
# 4                    Algeria
# 5                      Benin
# 6               Burkina Faso
# 7                      Ghana
# 8              Cote d'Ivoire
# 9                    Nigeria
# 10                     Niger
# 11                   Tunisia
# 12                      Togo
# 13                   Belgium
# 14                   Germany
# 15                   Estonia
# 16                   Finland
# 17            United Kingdom
# 18                  Guernsey
# 19                    Jersey
# 20               Isle of Man
# 21          Falkland Islands
# 22               Netherlands
# 23                   Ireland
# 24                   Denmark
# 25             Faroe Islands
# 26                Luxembourg
# 27                    Norway
# 28                    Poland
# 29                    Sweden
# ..                       ...
# ...

# %%
ds = pd.Series(airport[airport['DST']=='E']['Country'].unique()).sort_values()
ds.count()
# Out:
# 60

# %%
tz=airport[airport['Tz database time zone'].str.contains('Europe')]
tz
# Out:
#       Aiport                                    Name               City  \
# 296      299  Antwerp International Airport (Deurne)            Antwerp
# 297      300                    Beauvechain Air Base        Beauvechain
# 298      301                  Kleine Brogel Air Base      Kleine Brogel
# 299      302                        Brussels Airport           Brussels
# 300      303                     Jehonville Air Base            Bertrix
# 301      304        Brussels South Charleroi Airport          Charleroi
# 302      305                       Chièvres Air Base           Chievres
# 303      306                       Koksijde Air Base           Koksijde
# 304      307                      Florennes Air Base          Florennes
# 305      308                        Wevelgem Airport  Kortrijk-vevelgem
# 306      309                           Liège Airport              Liege
# 307      310     Ostend-Bruges International Airport             Ostend
# ...

# %%
tz1=pd.Series(tz['Country'].unique())
tz1

tz['Country'].unique()
# Out:
# array(['Belgium', 'Germany', 'Estonia', 'Finland', 'United Kingdom',
#        'Guernsey', 'Jersey', 'Isle of Man', 'Netherlands', 'Ireland',
#        'Denmark', 'Luxembourg', 'Norway', 'Poland', 'Sweden', 'Spain',
#        'Albania', 'Bulgaria', 'Cyprus', 'Croatia', 'France', 'Greece',
#        'Hungary', 'Italy', 'Slovenia', 'Czech Republic', 'Malta',
#        'Austria', 'Portugal', 'Bosnia and Herzegovina', 'Romania',
#        'Switzerland', 'Turkey', 'Moldova', 'Macedonia', 'Gibraltar',
#        'Serbia', 'Montenegro', 'Slovakia', 'Ukraine', 'Russia', 'Belarus',
#        'Latvia', 'Lithuania', 'United States'], dtype=object)

# %%
Europe=np.array(['Belgium', 'Germany', 'Estonia', 'Finland', 'United Kingdom', 
'Guernsey', 'Jersey', 'Isle of Man', 'Netherlands', 'Ireland', 
'Denmark', 'Luxembourg', 'Norway', 'Poland', 'Sweden', 'Spain', 
'Albania', 'Bulgaria', 'Cyprus', 'Croatia', 'France', 'Greece', 
'Hungary', 'Italy', 'Slovenia', 'Czech Republic', 'Malta', 
'Austria', 'Portugal', 'Bosnia and Herzegovina', 'Romania', 
'Switzerland', 'Turkey', 'Moldova', 'Macedonia', 'Gibraltar', 
'Serbia', 'Montenegro', 'Slovakia', 'Ukraine', 'Russia', 'Belarus', 
'Latvia', 'Lithuania', 'Iceland', 'Faroe Islands'])

# %%
np.setdiff1d(tz1,ds)
# Out:
# array(['Gibraltar', 'Russia'], dtype=object)

# %%
airport.replace('/N',NA)
short_name = airport[airport['ICAO'].str.len()!=4]
short_name
# Out:
#       Aiport                     Name           City           Country IATA  \
# 4409    5743             Kili Airport    Kili Island  Marshall Islands  KIO
# 4475    5814           Utirik Airport  Utirik Island  Marshall Islands  UTK
# 4737    6126  Aleknagik / New Airport      Aleknagik     United States  WKK
# 4741    6134     Akutan Seaplane Base         Akutan     United States  KQA
# 4742    6136     Lopez Island Airport          Lopez     United States  LPS
#
#      ICAO   Latitude   Longitude  Altitude Timezone DST Tz database time zone  \
# 4409  Q51   5.644515  169.119507         5       12   U        Pacific/Majuro
# 4475  03N  11.222000  169.852005         4       12   U        Pacific/Majuro
# 4737  5A8  59.282600 -158.617996        66       -9   A     America/Anchorage
# 4741  KQA  54.133770 -165.778896         0       -9   A     America/Anchorage
# 4742  S31  48.483898 -122.938004       209       -8   A   America/Los_Angeles
#
#          Type       Source
# ...

# %%
short_name1 = airport[airport['IATA'].str.len()!=3]
short_name1
# Out:
#       Aiport                          Name             City      Country IATA  \
# 56        57           Forestville Airport      Forestville       Canada   \N
# 103      104          Pitt Meadows Airport     Pitt Meadows       Canada   \N
# 205      207                 Blida Airport            Blida      Algeria   \N
# 206      208             Bou Saada Airport        Bou Saada      Algeria   \N
# 211      213               Reggane Airport           Reggan      Algeria   \N
# 213      215           Ain Oussera Airport      Ain Oussera      Algeria   \N
# 216      218              Mecheria Airport         Mecheria      Algeria   \N
# 217      219              Relizane Airport         Relizane      Algeria   \N
# 223      226              Bou Sfer Airport         Bou Sfer      Algeria   \N
# 229      232        Sidi Bel Abbes Airport   Sidi Bel Abbes      Algeria   \N
# 247      250                    Wa Airport               Wa        Ghana   \N
# ...

# %%
air_europe=airport[airport['Country'].isin(Europe)]
air_europe
# Out:
#       Aiport                                    Name               City  \
# 10        11                        Akureyri Airport           Akureyri
# 11        12                     Egilsstaðir Airport        Egilsstadir
# 12        13                    Hornafjörður Airport               Hofn
# 13        14                         Húsavík Airport            Husavik
# 14        15                      Ísafjörður Airport         Isafjordur
# 15        16          Keflavik International Airport           Keflavik
# 16        17                  Patreksfjörður Airport     Patreksfjordur
# 17        18                       Reykjavik Airport          Reykjavik
# 18        19                    Siglufjörður Airport       Siglufjordur
# 19        20                  Vestmannaeyjar Airport     Vestmannaeyjar
# 296      299  Antwerp International Airport (Deurne)            Antwerp
# 297      300                    Beauvechain Air Base        Beauvechain
# ...

# %%
short_namee=air_europe[air_europe['IATA'].str.len()!=3]
short_namee
# Out:
#       Aiport                          Name               City  Country IATA  \
# 297      300          Beauvechain Air Base        Beauvechain  Belgium   \N
# 298      301        Kleine Brogel Air Base      Kleine Brogel  Belgium   \N
# 300      303           Jehonville Air Base            Bertrix  Belgium   \N
# 302      305             Chièvres Air Base           Chievres  Belgium   \N
# 303      306             Koksijde Air Base           Koksijde  Belgium   \N
# 304      307            Florennes Air Base          Florennes  Belgium   \N
# 308      311            Zutendaal Air Base          Zutendaal  Belgium   \N
# 309      312      Limburg Regional Airport       Sint-truiden  Belgium   \N
# 310      313         Saint Hubert Air Base         St.-hubert  Belgium   \N
# 311      314                Ursel Air Base              Ursel  Belgium   \N
# 312      315               Weelde Air Base             Weelde  Belgium   \N
# ...
